# %%
import json
import os
import logging

def extract_text_from_json_files(directory, section_types):
    logging.basicConfig(level=logging.INFO)
    logging.info(f"Extracting text from JSON files in {directory}")

    for filename in os.listdir(directory):
        if filename.endswith(".json"):
            logging.info(f"Processing file {filename}")
            try:
                with open(os.path.join(directory, filename), 'r') as file:
                    data = json.load(file)
                    base_filename = os.path.splitext(filename)[0]
                    for section_type in section_types:
                        extracted_text = ""
                        for passage in data[0]['documents'][0]['passages']:
                            if passage['infons']['section_type'] == section_type:
                                extracted_text += passage['text'] + " "
                        output_filename = f"{base_filename}_{section_type}.txt"
                        with open(os.path.join(directory, output_filename), 'w', encoding='utf-8', errors='replace') as f:
                            f.write(extracted_text.strip())
                        logging.info(f"Wrote extracted text to {output_filename}")
            except json.JSONDecodeError as e:
                logging.error(f"Error parsing JSON file {filename}: {e}")
            except KeyError as e:
                logging.error(f"Error extracting text from JSON file {filename}: {e}")

if __name__ == "__main__":
    directory = 'C:/Users/mkha1/Documents/Copurification-Data-retrieval/Bash full text/100/'
    section_types = ['METHODS', 'RESULTS', 'CONCL', 'REF', 'FIG', 'SUPPL', 'DISCUSS']
    extract_text_from_json_files(directory, section_types)
# Out:
# INFO:root:Extracting text from JSON files in C:/Users/mkha1/Documents/Copurification-Data-retrieval/Bash full text/100/
# INFO:root:Processing file 34572064.json
# INFO:root:Wrote extracted text to 34572064_METHODS.txt
# INFO:root:Wrote extracted text to 34572064_RESULTS.txt
# INFO:root:Wrote extracted text to 34572064_CONCL.txt
# INFO:root:Wrote extracted text to 34572064_REF.txt
# INFO:root:Wrote extracted text to 34572064_FIG.txt
# INFO:root:Wrote extracted text to 34572064_SUPPL.txt
# INFO:root:Wrote extracted text to 34572064_DISCUSS.txt
# INFO:root:Processing file 34723793.json
# INFO:root:Wrote extracted text to 34723793_METHODS.txt
# INFO:root:Wrote extracted text to 34723793_RESULTS.txt
# INFO:root:Wrote extracted text to 34723793_CONCL.txt
# INFO:root:Wrote extracted text to 34723793_REF.txt
# INFO:root:Wrote extracted text to 34723793_FIG.txt
# INFO:root:Wrote extracted text to 34723793_SUPPL.txt
# INFO:root:Wrote extracted text to 34723793_DISCUSS.txt
# INFO:root:Processing file 34830424.json
# INFO:root:Wrote extracted text to 34830424_METHODS.txt
# INFO:root:Wrote extracted text to 34830424_RESULTS.txt
# INFO:root:Wrote extracted text to 34830424_CONCL.txt
# INFO:root:Wrote extracted text to 34830424_REF.txt
# INFO:root:Wrote extracted text to 34830424_FIG.txt
# INFO:root:Wrote extracted text to 34830424_SUPPL.txt
# INFO:root:Wrote extracted text to 34830424_DISCUSS.txt
# INFO:root:Processing file 34857632.json
# ERROR:root:Error parsing JSON file 34857632.json: Expecting value: line 1 column 1 (char 0)
# INFO:root:Processing file 35141172.json
# INFO:root:Wrote extracted text to 35141172_METHODS.txt
# INFO:root:Wrote extracted text to 35141172_RESULTS.txt
# INFO:root:Wrote extracted text to 35141172_CONCL.txt
# INFO:root:Wrote extracted text to 35141172_REF.txt
# INFO:root:Wrote extracted text to 35141172_FIG.txt
# INFO:root:Wrote extracted text to 35141172_SUPPL.txt
# INFO:root:Wrote extracted text to 35141172_DISCUSS.txt
# INFO:root:Processing file 35235778.json
# INFO:root:Wrote extracted text to 35235778_METHODS.txt
# INFO:root:Wrote extracted text to 35235778_RESULTS.txt
# INFO:root:Wrote extracted text to 35235778_CONCL.txt
# INFO:root:Wrote extracted text to 35235778_REF.txt
# INFO:root:Wrote extracted text to 35235778_FIG.txt
# INFO:root:Wrote extracted text to 35235778_SUPPL.txt
# INFO:root:Wrote extracted text to 35235778_DISCUSS.txt
# INFO:root:Processing file 35394875.json
# INFO:root:Wrote extracted text to 35394875_METHODS.txt
# INFO:root:Wrote extracted text to 35394875_RESULTS.txt
# INFO:root:Wrote extracted text to 35394875_CONCL.txt
# INFO:root:Wrote extracted text to 35394875_REF.txt
# INFO:root:Wrote extracted text to 35394875_FIG.txt
# INFO:root:Wrote extracted text to 35394875_SUPPL.txt
# INFO:root:Wrote extracted text to 35394875_DISCUSS.txt
