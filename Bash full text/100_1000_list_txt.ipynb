# %%
import pandas as pd
import numpy as np

# %%
pmid_pmc_list = np.load('pmidsPMC_'+'.npy')

# %%
pmid100 = pmid_pmc_list[:100]
print(len(pmid100))
np.savetxt('pmid100'+'.txt', pmid100, fmt='%s', delimiter=",")
# Out:
# 100

# %%
pmid1000 = pmid_pmc_list[:1000]
print(len(pmid1000))
np.savetxt('pmid1000'+'.txt', pmid1000, fmt='%s', delimiter=",")
# Out:
# 1000

# %%
pmid10000 = pmid_pmc_list[:10000]
print(len(pmid10000))
np.savetxt('pmid10000'+'.txt', pmid10000, fmt='%s', delimiter=",")
# Out:
# 10000
