# %%
import csv

# Open the input text file
with open('query_filename.txt', 'r') as file:
    # Read the file line by line
    lines = file.readlines()

# Remove the newline character from each line
lines = [line.strip() for line in lines]

# Open the output CSV file
with open('output_filename.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    
    # Write each line to the CSV file
    for line in lines:
        writer.writerow([line])  # Note the extra brackets to make it a list

# %%
print(len(lines))

# %%
import csv

csv_file_path = "output_filename.csv"
data = csv_to_list(csv_file_path)
print(len(data))

# %%
import random

random_ppers = random.sample(lines, 200)

# %%
with open("random_sample", "w") as f:
    f.writelines([key + "\n" for key in random_ppers])
